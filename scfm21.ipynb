# %%
# %matplotlib inline
import matplotlib as mpl
mpl.style.use('/Users/nik/Dropbox/Notebooks/thesisrc.py')
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import pandas as pd
import lvdatatools as lvdt

# %% [markdown]
# # SCFM21
#
# Cooled down to 4K in our leaky dilution fridge.

# %%
from IPython.display import Image, display

fig_dir = '/Volumes/EDDropbox/Data/scfm21/figures/'
display(Image(filename=os.path.join(fig_dir,'scfm21.jpg')))

# %% [markdown]
# ### 4K Data
#
# Only one file here.

# %%
data_dir = '/Volumes/EDDropbox/Data/scfm21/4K'
os.listdir(data_dir)
# Out:
# ['gateswp_10-12_6_a.txt', 'gateswp_10-12_6_a.bin', '._expandrive']

# %%
f = os.path.join(data_dir, 'gateswp_10-12_6_a.bin')
df = lvdt.get_data_2d(f)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(df['Gate'], df['Iavg']*1e9, label='bias = {0}mV'.format(1.0))
ax.set_title(r'$\verb|{0}|$'.format(f.split('/')[-1]))
ax.set_xlabel(r'$V_g (V)$')
ax.set_ylabel(r'I $(nA)$')
ax.legend(fontsize=16)

# %%
for h in lvdt.get_txt(f):
    print h
# Out:
# ['gate', '']
# ['Voltage Input Setup', ' ']
# ['Samples to Read', ' 2.40000E+3']
# ['Input Channel 1', ' Dev1/ai0']
# ['Sample Rate', ' 3.00000E+3']
# ['Input Minimum Value', ' -5.00000E+0']
# ['Input Maximum Value', ' 5.00000E+0']
# ['Terminal Configuration', ' Differential']
# ['Name', ' Measure']
# ['Sample Mode', ' Finite Samples']
# ['', '']
# ['Bias Output Options', ' ']
# ['DAQ Channel', ' Dev1/ao0']
# ['Minimum Value', ' -1.00000E+1']
# ['Maximum Value', ' 1.00000E+1']
# ['timeout', ' -1.00000E+0']
# ['Value (V)', ' 1.00000E-3']
# ['Divider', ' 1.00000E-3']
# ['Name', ' Bias']
# ['', '']
# ['Gate Sweep', ' ']
# ['Start (V)', ' 0.00000E+0']
# ['Stop (V)', ' 1.00000E+1']
# ['Step (V)', ' 5.00000E-3']
# ['Divider', ' 1.00000E+0']
# ['Physical Channel', ' Dev1/ao1']
# ['Name', ' Gate']
# ['Minimum Value', ' -1.00000E+1']
# ['Maximum Value', ' 1.00000E+1']
# ['Sweep Type', ' Symmetric About Start']
# ['Runs', ' 1.00000E+0']
# ['', '']
# ['Other', ' ']
# ...

# %% [markdown]
# Same shit I keep seeing in all of my samples.
