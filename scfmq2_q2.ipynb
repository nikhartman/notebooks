# %%
# %matplotlib inline
import matplotlib as mpl
mpl.style.use('/Users/nik/Dropbox/Notebooks/thesisrc.py')
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import pandas as pd
import lvdatatools as lvdt

# %%
rt_dir = '/Volumes/JUPITER/Data/scfmq2_q2/room_temp/'
cold_dir = '/Volumes/JUPITER/Data/scfmq2_q2/4K/'
fig_dir = '/Volumes/JUPITER/Data/scfmq2_q2/figures/'

# %%
def quick_plot_all(filename):
    """ for use in a for-loop when trolling through a whole folder of data.
        trying to catch exceptions as they arise. """
    dimension = lvdt.is_2d(filename)
    if dimension==2:
        try:
            df = lvdt.get_data_2d(filename)
            fig, ax = lvdt.plot_simple_2d(df)
        except(AttributeError, ValueError, IndexError): 
            return 'Fail -- 2d. A real problem.'
    elif dimension==3:
        try:
            df = lvdt.get_data_3d(filename)
            fig, ax, cb = lvdt.plot_simple_3d(df)
        except(AttributeError, ValueError, IndexError): 
            return 'Fail -- 3d. A real problem.'
    else:
        return 'Ignored. No .txt file to match.'
    ax.set_title(r'$\verb|{0}|$'.format(f.split('/')[-1]))
    return 'Pass -- {0}d. Good job, buddy.'.format(dimension)

# %%
for f in glob.glob(os.path.join(rt_dir, '*.bin')):
    print f
    quick_plot_all(f)
# Out:
# /Volumes/JUPITER/Data/scfmq2_q2/room_temp/gate_cooldown_1-5_16_a.bin
# /Volumes/JUPITER/Data/scfmq2_q2/room_temp/gateswp_1-5_16_a.bin

# %%
for f in glob.glob(os.path.join(cold_dir, '*.bin')):
    print f
    quick_plot_all(f)
# Out:
# /Volumes/JUPITER/Data/scfmq2_q2/4K/gateswp_1-5_16_d.bin
# /Volumes/JUPITER/Data/scfmq2_q2/4K/gateswp_1-5_16_e.bin

# %%
for f in glob.glob(os.path.join('/Volumes/JUPITER/Data/scfmq2_q2/', '*.bin')):
    print f
    quick_plot_all(f)
# Out:
# /Volumes/JUPITER/Data/scfmq2_q2/resistance_test_a.bin
# /Volumes/JUPITER/Data/scfmq2_q2/resistance_test_b.bin
# /Volumes/JUPITER/Data/scfmq2_q2/resistance_test_c.bin
# /Volumes/JUPITER/Data/scfmq2_q2/resistance_test_d.bin
