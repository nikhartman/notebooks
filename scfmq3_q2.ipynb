# %%
# %matplotlib inline
import matplotlib as mpl
mpl.style.use('/Users/nik/Dropbox/Notebooks/thesisrc.py')
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import pandas as pd
import lvdatatools as lvdt

# %%
def quick_plot_all(filename):
    """ for use in a for-loop when trolling through a whole folder of data.
        trying to catch exceptions as they arise. """
    dimension = lvdt.is_2d(filename)
    if dimension==2:
        try:
            df = lvdt.get_data_2d(filename)
            fig, ax = lvdt.plot_simple_2d(df)
        except(AttributeError, ValueError, IndexError): 
            return 'Fail -- 2d. A real problem.'
    elif dimension==3:
        try:
            df = lvdt.get_data_3d(filename)
            fig, ax, cb = lvdt.plot_simple_3d(df)
        except(AttributeError, ValueError, IndexError): 
            return 'Fail -- 3d. A real problem.'
    else:
        return 'Ignored. No .txt file to match.'
    ax.set_title(r'$\verb|{0}|$'.format(f.split('/')[-1]))
    return 'Pass -- {0}d. Good job, buddy.'.format(dimension)

# %%
rt_dir = '/Volumes/JUPITER/Data/scfmq3_q2/room_temp'
fig_dir = '/Volumes/JUPITER/Data/scfmf8/figures/'

# %%
for f in glob.glob(os.path.join(rt_dir, '*.bin')):
    print f
    quick_plot_all(f)
# Out:
# /Volumes/JUPITER/Data/scfmq3_q2/room_temp/cooldown_6-16-17_a.bin
# /Volumes/JUPITER/Data/scfmq3_q2/room_temp/cooldown_6-16-17_b.bin
# /Volumes/JUPITER/Data/scfmq3_q2/room_temp/cooldown_6-16-17_c.bin
# /Volumes/JUPITER/Data/scfmq3_q2/room_temp/gateswp_6-16_17_a.bin
# /Volumes/JUPITER/Data/scfmq3_q2/room_temp/gateswp_6-16_17_b.bin
# /Volumes/JUPITER/Data/scfmq3_q2/room_temp/gateswp_6-16_17_c.bin
