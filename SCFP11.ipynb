# %%
# %matplotlib inline
import matplotlib as mpl
mpl.style.use('/Users/nik/Dropbox/Notebooks/thesisrc.py')
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import pandas as pd
import lvdatatools as lvdt

# %% [markdown]
# # SCFP11
#
# Evaporated Co only. Measured in dunker.

# %%
from IPython.display import Image 

fig_dir = '/Volumes/EDDropbox/Data/SCFP11/figures/'
Image(filename=os.path.join(fig_dir,'scfp11.jpg'))

# %%
def quick_plot_any(filename):
    """ for use in a for-loop when trolling through a whole folder of data.
        trying to catch exceptions as they arise. """
    dimension = lvdt.is_2d(filename)
    if dimension==2:
        try:
            df = lvdt.get_data_2d(filename)
            fig, ax = lvdt.plot_simple_2d(df)
        except(AttributeError, ValueError, IndexError): 
            return 'Fail -- 2d. A real problem.'
    elif dimension==3:
        try:
            df = lvdt.get_data_3d(filename)
            fig, ax, cb = lvdt.plot_simple_3d(df)
        except(AttributeError, ValueError, IndexError): 
            return 'Fail -- 3d. A real problem.'
    else:
        return 'Ignored. No .txt file to match.'
    #ax.set_title(filename[:-4])
    return 'Pass -- {0}d. Good job, buddy.'.format(dimension)

# %%
data_dir = '/Volumes/EDDropbox/Data/SCFP11/dunker_cooldown/'
for i, f in enumerate(glob.glob(os.path.join(data_dir, '*.bin'))):
    print i, f.split('/')[-1]
# Out:
# 0 rt-4K_17-15_c.bin
# 1 rt-4K_17-15_a.bin
# 2 rt-4K_17-15_b.bin

# %%
for f in glob.glob(os.path.join(data_dir, '*.bin')):
    quick_plot_any(f)

# %%
data_dir = '/Volumes/EDDropbox/Data/SCFP11/4K/'
for i, f in enumerate(glob.glob(os.path.join(data_dir, '*.bin'))):
    print i, f.split('/')[-1]
# Out:
# 0 VI_17-15_a.bin
# 1 VI_17-15_b.bin
# 2 gate-swp_17-16_a.bin
# 3 gate-check_17-15_a.bin
# 4 gate-swp_17-15_a.bin
# 5 gate-swp_24-18_c.bin
# 6 VI_17-16_a.bin
# 7 VI_17-15_c.bin
# 8 gate-swp_17-16_b.bin
# 9 VI-gate-matrix_17-15_a.bin
# 10 gate-swp_24-18_b.bin
# 11 gate-swp_24-18_a.bin

# %%
for f in glob.glob(os.path.join(data_dir, '*.bin')):
    quick_plot_any(f)

# %% [markdown]
# Looks terrible. I think we're done here.
