# %%
# %matplotlib inline
import matplotlib as mpl
mpl.style.use('/Users/nik/Dropbox/Notebooks/thesisrc.py')
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import pandas as pd
import lvdatatools as lvdt

# %% [markdown]
# # SCFT20
#
# Ferromagnetic leads only. Cooled down to 4K. Bad gate leak.

# %%
from IPython.display import Image 

fig_dir = '/Volumes/EDDropbox/Data/SCFT20/figures/'
Image(filename=os.path.join(fig_dir,'scft20_q1.jpg'))

# %%
def quick_plot_any(filename):
    """ for use in a for-loop when trolling through a whole folder of data.
        trying to catch exceptions as they arise. """
    dimension = lvdt.is_2d(filename)
    if dimension==2:
        try:
            df = lvdt.get_data_2d(filename)
            fig, ax = lvdt.plot_simple_2d(df)
        except(AttributeError, ValueError, IndexError): 
            return 'Fail -- 2d. A real problem.'
    elif dimension==3:
        try:
            df = lvdt.get_data_3d(filename)
            fig, ax, cb = lvdt.plot_simple_3d(df)
        except(AttributeError, ValueError, IndexError): 
            return 'Fail -- 3d. A real problem.'
    else:
        return 'Ignored. No .txt file to match.'
    #ax.set_title(filename[:-4])
    return 'Pass -- {0}d. Good job, buddy.'.format(dimension)

# %%
reload(lvdt)

data_dir = '/Volumes/EDDropbox/Data/SCFT20/cool down/'
os.listdir(data_dir)
# Out:
# ['gate-swp_10-9_a.txt',
#  'gate-swp_10-9_f.bin',
#  'gate-swp_10-9_c_quick-plot.png',
#  'gate-swp_10-9_e.bin',
#  'gate-swp_10-9_e.txt',
#  'gate-swp_10-9_c.txt',
#  'gate-swp_10-9_a_quick-plot.png',
#  'gate-swp_10-9_b.txt',
#  'gate-swp_10-9_c.bin',
#  'gate-swp_10-9_a.bin',
#  'gate-swp_10-9_e_quick-plot.png',
#  'gate-swp_10-9_d.bin',
#  'gate-swp_10-9_b_quick-plot.png',
#  'gate-swp_10-9_b.bin']

# %%
for f in glob.glob(os.path.join(data_dir, '*.bin')):
    quick_plot_any(f)
