# %%
# %matplotlib inline
import matplotlib as mpl
mpl.style.use('/Users/nik/Dropbox/Notebooks/thesisrc.py')
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import pandas as pd
import lvdatatools as lvdt

# %% [markdown]
# # scfmc6
#
# Pd only device. Made with mask aligner markers, ebeam bonding pads, sputtered Pd contacts.

# %%
from IPython.display import Image 

fig_dir =  '/Volumes/EDDropbox/Data/scfmc6/figures/'
Image(filename=os.path.join(fig_dir,'scfmc6_q1.jpg'))

# %%
Image(filename=os.path.join(fig_dir,'scfmc6_q2.jpg'))

# %% [markdown]
# ### Room Temp Data

# %%
data_dir = '/Volumes/EDDropbox/Data/scfmc6/room_temp/'
for f in glob.glob(os.path.join(data_dir, '*.bin')):
    print f.split('/')[-1]
# Out:
# gateswp_17-16-6_a.bin
# gateswp_14-11-6_no-safety-res.bin
# gateswp_14-11-6_no-safety-res_bckwrds.bin
# gateswp_14-11-6_a.bin
# gateswp_14-11-6_b.bin
# gateswp_14-11-6_vacuum_no-safety.bin

# %%
def quick_plot_any(filename):
    """ for use in a for-loop when trolling through a whole folder of data.
        trying to catch exceptions as they arise. """
    dimension = lvdt.is_2d(filename)
    if dimension==2:
        try:
            df = lvdt.get_data_2d(filename)
            fig, ax = lvdt.plot_simple_2d(df)
        except(AttributeError, ValueError, IndexError): 
            return 'Fail -- 2d. A real problem.'
    elif dimension==3:
        try:
            df = lvdt.get_data_3d(filename)
            fig, ax, cb = lvdt.plot_simple_3d(df)
        except(AttributeError, ValueError, IndexError): 
            return 'Fail -- 3d. A real problem.'
    else:
        return 'Ignored. No .txt file to match.'
    ax.set_title(r'$\verb|{0}|$'.format(filename.split('/')[-1]))
    return 'Pass -- {0}d. Good job, buddy.'.format(dimension)

# %%
for f in glob.glob(os.path.join(data_dir, '*.bin')):
    quick_plot_any(f)

# %% [markdown]
# ### 4K Data

# %%
data_dir = '/Volumes/EDDropbox/Data/scfmc6/'
for f in glob.glob(os.path.join(data_dir, '*.bin')):
    print f.split('/')[-1]
# Out:
# vi-gate_14-11_6_b.bin
# gateswp_14-11-6_f.bin
# cool-down_14-11-6_d.bin
# cool-down_14-11-6_c.bin
# cool-down_14-11-6_b.bin
# cool-down_14-11-6_a.bin
# cool-down_14-11-6_e.bin
# gateswp_14-11-6_e.bin

# %%
for f in glob.glob(os.path.join(data_dir, '*.bin')):
    quick_plot_any(f)

# %% [markdown]
# Not much of a quantum dot, but, cool. That plotting function works great. It's going to save me tons of time today.
