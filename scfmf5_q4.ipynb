# %%
# %matplotlib inline
import matplotlib as mpl
mpl.style.use('/Users/nik/Dropbox/Notebooks/thesisrc.py')
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import pandas as pd
import lvdatatools as lvdt

# %%
rt_dir = '/Volumes/JUPITER/Data/scfmf5_q4/room_temp/'
cold_dir = '/Volumes/JUPITER/Data/scfmf5_q4/4K/'
fig_dir = '/Volumes/JUPITER/Data/scfmf5_q4/figures/'

# %%
def quick_plot_all(filename):
    """ for use in a for-loop when trolling through a whole folder of data.
        trying to catch exceptions as they arise. """
    dimension = lvdt.is_2d(filename)
    if dimension==2:
        try:
            df = lvdt.get_data_2d(filename)
            fig, ax = lvdt.plot_simple_2d(df)
        except(AttributeError, ValueError, IndexError): 
            return 'Fail -- 2d. A real problem.'
    elif dimension==3:
        try:
            df = lvdt.get_data_3d(filename)
            fig, ax, cb = lvdt.plot_simple_3d(df)
        except(AttributeError, ValueError, IndexError): 
            return 'Fail -- 3d. A real problem.'
    else:
        return 'Ignored. No .txt file to match.'
    ax.set_title(r'$\verb|{0}|$'.format(f.split('/')[-1]))
    return 'Pass -- {0}d. Good job, buddy.'.format(dimension)

# %%
for f in glob.glob(os.path.join(rt_dir, '*.bin')):
    print f
    try: quick_plot_all(f)
    except:
        print "Oops!"
# Out:
# /Volumes/JUPITER/Data/scfmf5_q4/room_temp/cooldown_19-20_1-10_d.bin
# /Volumes/JUPITER/Data/scfmf5_q4/room_temp/cooldown_19-20_1-10_e.bin
# /Volumes/JUPITER/Data/scfmf5_q4/room_temp/gateswp_19-20_1-10_a.bin
# /Volumes/JUPITER/Data/scfmf5_q4/room_temp/gateswp_19-20_1-10_b.bin
# /Volumes/JUPITER/Data/scfmf5_q4/room_temp/gateswp_19-20_1-10_c.bin
# /Volumes/JUPITER/Data/scfmf5_q4/room_temp/gateswp_19-20_1-10_d.bin
# /Volumes/JUPITER/Data/scfmf5_q4/room_temp/gateswp_19-20_1-10_e.bin
# /Volumes/JUPITER/Data/scfmf5_q4/room_temp/topgateswp_19-20_1-10_b.bin
# /Volumes/JUPITER/Data/scfmf5_q4/room_temp/topgateswp_19-20_1-10_c.bin
# /Volumes/JUPITER/Data/scfmf5_q4/room_temp/topgateswp_19-20_1-10_d.bin

# %%
for f in glob.glob(os.path.join(cold_dir, '*.bin')):
    print f
    try: quick_plot_all(f)
    except:
        print "Oops!"
# Out:
# /Volumes/JUPITER/Data/scfmf5_q4/4K/gateswp_19-20_1-10_a.bin
# /Volumes/JUPITER/Data/scfmf5_q4/4K/gateswp_19-20_1-10_b.bin
# /Volumes/JUPITER/Data/scfmf5_q4/4K/topgateswp_19-20_1-10_d.bin
# /Volumes/JUPITER/Data/scfmf5_q4/4K/topgateswp_19-20_1-10_e.bin
# /Volumes/JUPITER/Data/scfmf5_q4/4K/topgateswp_19-20_1-10_g.bin
# /Volumes/JUPITER/Data/scfmf5_q4/4K/topgateswp_19-20_1-10_h.bin
# /Volumes/JUPITER/Data/scfmf5_q4/4K/whydontyouwork_a.bin

# %% [markdown]
# This was the one that froze to death when I cooled it down. That's very strange given that it was a cobalt sample. Maybe the topgate had some adverse effect on it? Actually, it could have been the additional liftoff step, since acetone does destroy these sputtered cobalt samples pretty quickly.
