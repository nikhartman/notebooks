# %%
# %matplotlib inline
import matplotlib as mpl
mpl.style.use('/Users/nik/Dropbox/Notebooks/thesisrc.py')
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import pandas as pd
import lvdatatools as lvdt

# %% [markdown]
# ## MT1_2

# %% [markdown]
# This data is super old. It's going to take a minute to figure out how to read it...

# %%
# data_dir = '/Volumes/EDDropbox/Data/MT1_2/Gp_V/'
# data_dir = '/Volumes/EDDropbox/Data/MT1_2/Gp_Vbg/'

from IPython.display import Image 

fig_dir = '/Volumes/EDDropbox/Data/MT1_2/figures/'
Image(filename=os.path.join(fig_dir,'MT1_q4.jpg'))

# %%
data_dir = '/Volumes/EDDropbox/Data/MT1_2/Gp_V/'
os.listdir(data_dir)
# Out:
# ['I-14-20_V-8-20_4p4K_0T_1.txt', 'I-14-20_V-8-20_4p4K_0T_2.txt']

# %%
f = os.path.join(data_dir,'I-14-20_V-8-20_4p4K_0T_1.txt')
# fo = open(f)
# for line in fo:
#     print line

# I think this goes [Bias Resistance Conductance ... ]
# I think this goes [Bias Resistance Conductance ... ]

data = np.loadtxt(f)
gate = data[:,0]
r = data[:,1]/1000 # in kOhms
g = data[:,2]/3.875e-5 # in e^/h

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(gate, r)
ax.set_xlabel(r'$V_g (V)$')
ax.set_ylabel(r'$R (k \Omega)$')
# ax.text(50.0, 11., r'$V_b = 5mV$')

# %%
f = os.path.join(data_dir,'I-14-20_V-8-20_4p4K_0T_1.txt')
# fo = open(f)
# for line in fo:
#     print line

data = np.loadtxt(f)
gate = data[:,0]
r = data[:,1]/1000 # in kOhms
g = data[:,2]/3.875e-5 # in e^/h

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(gate, g)
ax.set_xlabel(r'$V_g (V)$')
ax.set_ylabel(r'$G (\frac{e^2}{h})$')

# %%
f = os.path.join(data_dir,'I-14-20_V-8-20_4p4K_0T_2.txt')

data = np.loadtxt(f)
gate = data[:,0]
r = data[:,1]/1000 # in kOhms
g = data[:,2]/3.875e-5 # in e^/h

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(gate, r)
ax.set_xlabel(r'$V_g (V)$')
ax.set_ylabel(r'$R (k \Omega)$')
# ax.text(50.0, 11., r'$V_b = 5mV$')

# %%
f = os.path.join(data_dir,'I-14-20_V-8-20_4p4K_0T_2.txt')

data = np.loadtxt(f)
gate = data[:,0]
r = data[:,1]/1000 # in kOhms
g = data[:,2]/3.875e-5 # in e^/h

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(gate, g)
ax.set_xlabel(r'$V_g (V)$')
ax.set_ylabel(r'$G (\frac{e^2}{h})$')

# %%
data_dir = '/Volumes/EDDropbox/Data/MT1_2/Gp_Vbg/'
os.listdir(data_dir)
# Out:
# ['I_11-7_V-8-10_4p2K_1.txt']

# %%
f = os.path.join(data_dir,'I_11-7_V-8-10_4p2K_1.txt')
# fo = open(f)
# for line in fo:
#     print line

# This one is [Gate Resistance Conductance ...]

data = np.loadtxt(f)
gate = data[:,0]
r = data[:,1]/1000 # in kOhms
g = data[:,2]/3.875e-5 # in e^/h

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(gate, r)
ax.set_xlabel(r'$V_g (V)$')
ax.set_ylabel(r'$R (k \Omega)$')
# ax.text(50.0, 11., r'$V_b = 5mV$')

# %%
f = os.path.join(data_dir,'I_11-7_V-8-10_4p2K_1.txt')

data = np.loadtxt(f)
gate = data[:,0]
r = data[:,1]/1000 # in kOhms
g = data[:,2]/3.875e-5 # in e^/h

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(gate, g)
ax.set_xlabel(r'$V_g (V)$')
ax.set_ylabel(r'$G (\frac{e^2}{h})$')

# %% [markdown]
# Looks like this sample was abandoned due to boring gate behavior. Hard to tell since this was a lock in measurement.
#
# This was also a 4 probe measurement? Atikur... what the hell?
