# %%
# %matplotlib inline
import matplotlib as mpl
mpl.style.use('/Users/nik/Dropbox/Notebooks/thesisrc.py')
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import pandas as pd
import lvdatatools as lvdt

# %% [markdown]
# # SCF96
#
# FM only. Etched Mo optical leads leads. Standard growth. Ebeam evaporated Co leads.

# %%
from IPython.display import display, Image

fig_dir = '/Volumes/EDDropbox/Data/SCF96/figures/'
display(Image(os.path.join(fig_dir, 'scf96_q1.jpg')))
display(Image(os.path.join(fig_dir, 'scf96_q3.jpg')))

# %% [markdown]
# ## q1

# %% [markdown]
# ### Gate Sweeps

# %%
data_dir = '/Volumes/EDDropbox/Data/SCF96/q1'

# if I look for log files, I can ignore all of the time series files
flist = []
for i, f in enumerate(glob.glob(os.path.join(data_dir, '*gate-i*.txt'))):
    s = f.split('/')[-1][:-4]
    print '{0} -- \'{1}\' '.format(i, s)
    flist.append(os.path.join(data_dir, s+'.bin'))
# Out:
# 0 -- 'gate-i_9-12_23_a'
# 1 -- 'gate-i_9-12_23_b'
# 2 -- 'gate-i_9-12_23_d'
# 3 -- 'gate-i_9-12_23_e'
# 4 -- 'gate-i_9-12_23_c'

# %%
for f in flist:
    if os.path.isfile(f):
        df = lvdt.get_data_2d(f)

        fig = plt.figure()
        ax = fig.add_subplot(1,1,1)
        ax.plot(df['Gate'], df['Iavg']*1e9)
        ax.set_title(r'$\verb|{0}|$'.format(f.split('/')[-1]))
        ax.set_xlabel(r'$V_g (V)$')
        ax.set_ylabel(r'I $(nA)$')
        ax.legend(fontsize=16)
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_axes.py:475: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# ### Bias/Gate Sweeps

# %%
data_dir = '/Volumes/EDDropbox/Data/SCF96/q1'

# if I look for log files, I can ignore all of the time series files for now
flist = []
for i, f in enumerate(glob.glob(os.path.join(data_dir, '*vi-gate*.txt'))):
    s = f.split('/')[-1][:-4]
    print '{0} -- \'{1}\' '.format(i, s)
    flist.append(os.path.join(data_dir, s+'.bin'))
# Out:
# 0 -- 'vi-gate_9-12_23_b'
# 1 -- 'vi-gate_9-12_23_f'
# 2 -- 'vi-gate_9-12_23_c'
# 3 -- 'vi-gate_9-12_23_e'
# 4 -- 'vi-gate_9-12_23_a'
# 5 -- 'vi-gate_9-12_23_f_2T'

# %%
for f in flist:
    if os.path.isfile(f):
        try:
            df = lvdt.get_data_3d(f)
            df = df.groupby(df.index).mean()

            fig = plt.figure(figsize=(14,8))
            ax = fig.add_subplot(1,1,1)
            limits = lvdt.df_extent(df)
            im = ax.imshow(df*1e9, extent = limits, 
                           cmap = plt.cm.seismic,
                           origin = 'lower', aspect = 'auto', interpolation = 'nearest')
            ax.set_xlabel(r'$V_g (V)$')
            ax.set_ylabel(r'$V_b (mV)$')
            ax.set_title(r'$\verb|{0}|$'.format(f.split('/')[-1]))
            cb = plt.colorbar(im)
            cb.set_label(r'$I (nA)$')
        except ValueError, msg:
            print msg
# Out:
# total size of new array must be unchanged
# total size of new array must be unchanged
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_base.py:2562: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=3.0, right=3.0
#   'left=%s, right=%s') % (left, right))

# %% [markdown]
# ### Field Sweeps

# %%
data_dir = '/Volumes/EDDropbox/Data/SCF96/q1'

# if I look for log files, I can ignore all of the time series files for now
flist = []
for i, f in enumerate(glob.glob(os.path.join(data_dir, '*bi*.txt'))):
    s = f.split('/')[-1][:-4]
    print '{0} -- \'{1}\' '.format(i, s)
    flist.append(os.path.join(data_dir, s+'.bin'))
# Out:
# 0 -- 'bi_9-12_23_b'
# 1 -- 'bi_9-12_23_c'
# 2 -- 'bi_9-12_23_a'
# 3 -- 'bi_9-12_23_d'

# %%
for f in flist:
    if os.path.isfile(f):
        try:
            df = lvdt.get_data_2d(f)

            fig = plt.figure()
            ax = fig.add_subplot(1,1,1)
            ax.plot(df['Field'], df['Iavg']*1e9)
            ax.set_title(r'$\verb|{0}|$'.format(f.split('/')[-1]))
            ax.set_xlabel(r'$B (T)$')
            ax.set_ylabel(r'I $(nA)$')
            ax.legend(fontsize=16)
        except ValueError, msg:
            print msg

# %% [markdown]
# ## q3

# %% [markdown]
# ### Gate Sweeps

# %%
data_dir = '/Volumes/EDDropbox/Data/SCF96/q3'

# if I look for log files, I can ignore all of the time series files
flist = []
for i, f in enumerate(glob.glob(os.path.join(data_dir, '*gate-i*.txt'))):
    s = f.split('/')[-1][:-4]
    print '{0} -- \'{1}\' '.format(i, s)
    flist.append(os.path.join(data_dir, s+'.bin'))
# Out:
# 0 -- 'gate-i_18-20_23_a'
# 1 -- 'gate-i_16-17_23_b'
# 2 -- 'gate-i_13-18_23_a'
# 3 -- 'gate-i_16-17_23_a'
# 4 -- 'gate-i_18-20_23_b'
# 5 -- 'gate-i_15-16_23_a'

# %%
for f in flist:
    print f
    if os.path.isfile(f):
        try:
            print 'trying -- ', f
            df = lvdt.get_data_2d(f)

            fig = plt.figure()
            ax = fig.add_subplot(1,1,1)
            ax.plot(df['Gate'], df['Iavg']*1e9)
            ax.set_title(r'$\verb|{0}|$'.format(f.split('/')[-1]))
            ax.set_xlabel(r'$V_g (V)$')
            ax.set_ylabel(r'I $(nA)$')
        except ValueError, msg:
            print msg
# Out:
# /Volumes/EDDropbox/Data/SCF96/q3/gate-i_18-20_23_a.bin
# trying --  /Volumes/EDDropbox/Data/SCF96/q3/gate-i_18-20_23_a.bin
# /Volumes/EDDropbox/Data/SCF96/q3/gate-i_16-17_23_b.bin
# trying --  /Volumes/EDDropbox/Data/SCF96/q3/gate-i_16-17_23_b.bin
# /Volumes/EDDropbox/Data/SCF96/q3/gate-i_13-18_23_a.bin
# trying --  /Volumes/EDDropbox/Data/SCF96/q3/gate-i_13-18_23_a.bin
# /Volumes/EDDropbox/Data/SCF96/q3/gate-i_16-17_23_a.bin
# trying --  /Volumes/EDDropbox/Data/SCF96/q3/gate-i_16-17_23_a.bin
# /Volumes/EDDropbox/Data/SCF96/q3/gate-i_18-20_23_b.bin
# trying --  /Volumes/EDDropbox/Data/SCF96/q3/gate-i_18-20_23_b.bin
# /Volumes/EDDropbox/Data/SCF96/q3/gate-i_15-16_23_a.bin
# trying --  /Volumes/EDDropbox/Data/SCF96/q3/gate-i_15-16_23_a.bin

# %% [markdown]
# Big DC offsets. The last one looks reasonable, though.

# %% [markdown]
# ### Bias/Gate Sweeps

# %%
data_dir = '/Volumes/EDDropbox/Data/SCF96/q3'

# if I look for log files, I can ignore all of the time series files for now
flist = []
for i, f in enumerate(glob.glob(os.path.join(data_dir, '*vi-gate*.txt'))):
    s = f.split('/')[-1][:-4]
    print '{0} -- \'{1}\' '.format(i, s)
    flist.append(os.path.join(data_dir, s+'.bin'))
# Out:
# 0 -- 'vi-gate_16-17_23_a_2T'
# 1 -- 'vi-gate_16-17_23_a'

# %%
for f in flist:
    if os.path.isfile(f):
        try:
            df = lvdt.get_data_3d(f)
            df = df.groupby(df.index).mean()

            fig = plt.figure(figsize=(14,8))
            ax = fig.add_subplot(1,1,1)
            limits = lvdt.df_extent(df)
            im = ax.imshow(df*1e9, extent = limits, 
                           cmap = plt.cm.seismic,
                           origin = 'lower', aspect = 'auto', interpolation = 'nearest')
            ax.set_xlabel(r'$V_g (V)$')
            ax.set_ylabel(r'$V_b (mV)$')
            ax.set_title(r'$\verb|{0}|$'.format(f.split('/')[-1]))
            cb = plt.colorbar(im)
            cb.set_label(r'$I (nA)$')
        except ValueError, msg:
            print msg

# %% [markdown]
# Nice.

# %% [markdown]
# ### Field Sweeps

# %%
data_dir = '/Volumes/EDDropbox/Data/SCF96/q3'

# if I look for log files, I can ignore all of the time series files for now
flist = []
for i, f in enumerate(glob.glob(os.path.join(data_dir, '*bi*.txt'))):
    s = f.split('/')[-1][:-4]
    print '{0} -- \'{1}\' '.format(i, s)
    flist.append(os.path.join(data_dir, s+'.bin'))
# Out:
# 0 -- 'bi_16-17_23_multiple-runs_d'
# 1 -- 'bi_16-17_23_multiple-runs_c'
# 2 -- 'bi_16-17_23_multiple-runs_b'
# 3 -- 'bi_16-17_23_multiple-runs_e'
# 4 -- 'bi_16-17_23_multiple-runs_f'

# %%
for f in flist:
    if os.path.isfile(f):
        try:
            df = lvdt.get_data_2d(f)

            fig = plt.figure()
            ax = fig.add_subplot(1,1,1)
            ax.plot(df['Field'], df['Iavg']*1e9)
            ax.set_title(r'$\verb|{0}|$'.format(f.split('/')[-1]))
            ax.set_xlabel(r'$B (T)$')
            ax.set_ylabel(r'I $(nA)$')
        except ValueError, msg:
            print msg

# %% [markdown]
# ### Field/Bias Sweep

# %%
data_dir = '/Volumes/EDDropbox/Data/SCF96/q3'

# if I look for log files, I can ignore all of the time series files for now
flist = []
for i, f in enumerate(glob.glob(os.path.join(data_dir, '*vi-bswp*.txt'))):
    s = f.split('/')[-1][:-4]
    print '{0} -- \'{1}\' '.format(i, s)
    flist.append(os.path.join(data_dir, s+'.bin'))
# Out:
# 0 -- 'vi-bswp_16-17_23_b'
# 1 -- 'vi-bswp_16-17_23_c'
# 2 -- 'vi-bswp_16-17_23_a'

# %%
# this seems to be the only good one

df = lvdt.get_data_3d(flist[1])
ind = np.where(np.diff(df.columns)==0)[0]
cuts = np.concatenate(([0],ind,[len(df.columns)-1]), axis=0)
df = df.groupby(df.index).mean()
df.index = df.index*1000

fig, ax = plt.subplots(2,1, figsize=(14,8))

limits = [df.columns[cuts[0]], df.columns[cuts[1]], df.index.min(), df.index.max()]
im0 = ax[0].imshow(df.iloc[:,cuts[0]:cuts[1]]*1e9, extent = limits, 
               cmap = plt.cm.seismic,
               origin = 'lower', aspect = 'auto', interpolation = 'nearest')
#ax[0].set_xlabel(r'$V_g (V)$')
ax[0].set_ylabel(r'$V_b (mV)$')
ax[0].set_title('Up')
#cb0 = plt.colorbar(im0)
#cb0.set_label(r'$I (nA)$')

limits = [df.columns[cuts[1]], df.columns[cuts[-1]], df.index.min(), df.index.max()]
im1 = ax[1].imshow(df.iloc[:,cuts[1]:cuts[-1]]*1e9, extent = limits, 
               cmap = plt.cm.seismic,
               origin = 'lower', aspect = 'auto', interpolation = 'nearest')
#ax[0].set_xlabel(r'$V_g (V)$')
ax[1].set_ylabel(r'$V_b (mV)$')
ax[1].set_xlabel(r'$B (T)$')
ax[1].set_title('Down')
fig.suptitle(r'$\verb|{0}|$'.format(f.split('/')[-1]))
